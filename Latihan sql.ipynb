# %%
import os
import pymysql
import pandas as pd
host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df=pd.read_sql_query(sql,conn)
    return df

# %%
run("SHOW TABLEs")
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %%
run("SELECT * FROM offices")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          1  San Francisco   +1 650 219 4782         100 Market Street
# 1          2         Boston   +1 215 837 0825          1550 Court Place
# 2          3            NYC   +1 212 555 3000      523 East 53rd Street
# 3          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 6          7         London  +44 20 7877 2041       25 Old Broad Street
#
#   addressLine2       state    country postalCode territory
# 0    Suite 300          CA        USA      94080        NA
# 1    Suite 102          MA        USA      02107        NA
# 2      apt. 5A          NY        USA      10022        NA
# 3         None        None     France      75017      EMEA
# 4         None  Chiyoda-Ku      Japan   102-8578     Japan
# ...

# %%
run("SELECT city, state,country FROM offices")
# Out:
#             city       state    country
# 0  San Francisco          CA        USA
# 1         Boston          MA        USA
# 2            NYC          NY        USA
# 3          Paris        None     France
# 4          Tokyo  Chiyoda-Ku      Japan
# 5         Sydney        None  Australia
# 6         London        None         UK

# %%
run("SELECT * from employees")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
run("SELECT COUNT(employeeNumber) As TotalEmployee from employees")
# Out:
#    TotalEmployee
# 0             23

# %%
run("SELECT * from payments")
# Out:
#      customerNumber checkNumber paymentDate     amount
# 0               103    HQ336336  2004-10-19    6066.78
# 1               103    JM555205  2003-06-05   14571.44
# 2               103    OM314933  2004-12-18    1676.14
# 3               112    BO864823  2004-12-17   14191.12
# 4               112     HQ55022  2003-06-06   32641.98
# 5               112    ND748579  2004-08-20   33347.88
# 6               114     GG31455  2003-05-20   45864.03
# 7               114    MA765515  2004-12-15   82261.22
# 8               114    NP603840  2003-05-31    7565.08
# 9               114     NR27552  2004-03-10   44894.74
# 10              119    DB933704  2004-11-14   19501.82
# 11              119    LN373447  2004-08-08   47924.19
# 12              119     NG94694  2005-02-22   49523.67
# 13              121    DB889831  2003-02-16   50218.95
# 14              121    FD317790  2003-10-28    1491.38
# 15              121    KI831359  2004-11-04   17876.32
# ...

# %%
run("SELECT SUM(amount) AS TotalPayments from payments ")
# Out:
#    TotalPayments
# 0     8853839.23

# %%
run("SELECT * from productlines")
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %%
run("SELECT productLine from productlines WHERE productline LIKE '%Cars%'")
# Out:
#     productLine
# 0  Classic Cars
# 1  Vintage Cars

# %%
run("SELECT SUM(amount) from payments WHERE paymentDate='2004-10-28'")
# Out:
#    SUM(amount)
# 0     47411.33

# %%
run("SELECT * from payments WHERE amount>100000 ")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %%
run("SELECT * from products")
# Out:
#     productCode                                  productName  \
# 0      S10_1678        1969 Harley Davidson Ultimate Chopper
# 1      S10_1949                     1952 Alpine Renault 1300
# 2      S10_2016                        1996 Moto Guzzi 1100i
# 3      S10_4698         2003 Harley-Davidson Eagle Drag Bike
# 4      S10_4757                          1972 Alfa Romeo GTA
# 5      S10_4962                       1962 LanciaA Delta 16V
# 6      S12_1099                            1968 Ford Mustang
# 7      S12_1108                            2001 Ferrari Enzo
# 8      S12_1666                               1958 Setra Bus
# 9      S12_2823                             2002 Suzuki XREO
# 10     S12_3148                           1969 Corvair Monza
# 11     S12_3380                           1968 Dodge Charger
# 12     S12_3891                             1969 Ford Falcon
# 13     S12_3990                      1970 Plymouth Hemi Cuda
# ...

# %%
run("SELECT productName, productline from products ORDER BY productLine")
# Out:
#                                      productName       productline
# 0                       1952 Alpine Renault 1300      Classic Cars
# 1                            1972 Alfa Romeo GTA      Classic Cars
# 2                         1962 LanciaA Delta 16V      Classic Cars
# 3                              1968 Ford Mustang      Classic Cars
# 4                              2001 Ferrari Enzo      Classic Cars
# 5                             1969 Corvair Monza      Classic Cars
# 6                             1968 Dodge Charger      Classic Cars
# 7                               1969 Ford Falcon      Classic Cars
# 8                        1970 Plymouth Hemi Cuda      Classic Cars
# 9                             1969 Dodge Charger      Classic Cars
# 10                               1993 Mazda RX-7      Classic Cars
# 11                         1965 Aston Martin DB5      Classic Cars
# 12                   1948 Porsche 356-A Roadster      Classic Cars
# ...

# %%
run("SELECT productline, COUNT(productName) AS TotalUnit from products GROUP BY productLine")
# Out:
#         productline  TotalUnit
# 0      Classic Cars         38
# 1       Motorcycles         13
# 2            Planes         12
# 3             Ships          9
# 4            Trains          3
# 5  Trucks and Buses         11
# 6      Vintage Cars         24

# %%
run("SELECT MIN(amount) FROM payments")
# Out:
#    MIN(amount)
# 0       615.45

# %%
run("SELECT customernumber, amount FROM payments HAVING amount<616")
# Out:
#    customernumber  amount
# 0             398  615.45

# %%
run("SELECT AVG(amount) FROM payments")
# Out:
#     AVG(amount)
# 0  32431.645531

# %%
run("SELECT * from payments where amount> (2*32431.645531)")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %%
run("SELECT * from products")
# Out:
#     productCode                                  productName  \
# 0      S10_1678        1969 Harley Davidson Ultimate Chopper
# 1      S10_1949                     1952 Alpine Renault 1300
# 2      S10_2016                        1996 Moto Guzzi 1100i
# 3      S10_4698         2003 Harley-Davidson Eagle Drag Bike
# 4      S10_4757                          1972 Alfa Romeo GTA
# 5      S10_4962                       1962 LanciaA Delta 16V
# 6      S12_1099                            1968 Ford Mustang
# 7      S12_1108                            2001 Ferrari Enzo
# 8      S12_1666                               1958 Setra Bus
# 9      S12_2823                             2002 Suzuki XREO
# 10     S12_3148                           1969 Corvair Monza
# 11     S12_3380                           1968 Dodge Charger
# 12     S12_3891                             1969 Ford Falcon
# 13     S12_3990                      1970 Plymouth Hemi Cuda
# ...

# %%
import sqlite3

# %%
from decimal import Decimal

# #percentage=[]
# MSRP=run("SELECT MSRP from products")
# buy="SELECT buyPrice from products"
# percentage.append(float(MSRP))
# # for x in buy:
# #     percent=((int(x)*int(MSRP)/100)+100
# #     cursor.execute(percent)
# cursor.execute(MSRP)
# percentage=list(cursor.fetchall())#     percentage.extend(cursor.fetchall())
# print (percentage)

connection= sqlite3.connect('mysqlsampledatabase.sql')
curs = conn.cursor()
curs.execute('SELECT MSRP from products')
result=curs.fetchall()
output=[]
MSRP=[]
c=0
for i in result:
    output.append(list(map(float,list(i))))
while c<len(output):
    b=output[c][0]
    MSRP.append(b)
    c=c+1
print(MSRP)



curs = conn.cursor()
curs.execute('SELECT buyPrice from products')
final2=curs.fetchall()
out=[]
buyPrice=[]
z=0
for i in final2:
    out.append(list(map(float,list(i))))
while z<len(out):
    p=out[z][0]
    buyPrice.append(p)
    z=z+1
print(buyPrice)
# Out:
# [95.7, 214.3, 118.94, 193.66, 136.0, 147.74, 194.57, 207.8, 136.67, 150.62, 151.08, 117.44, 173.02, 79.8, 118.5, 115.16, 116.67, 141.54, 102.74, 53.91, 124.44, 157.69, 170.0, 77.0, 142.25, 163.73, 60.54, 122.73, 127.13, 60.77, 84.48, 60.57, 168.75, 132.0, 101.31, 62.46, 86.02, 104.72, 136.59, 169.34, 107.57, 100.84, 80.41, 99.21, 146.99, 141.28, 62.17, 105.87, 143.62, 92.03, 87.77, 121.08, 50.31, 148.8, 71.27, 73.49, 57.8, 112.7, 50.31, 109.42, 33.19, 76.17, 122.89, 44.8, 127.79, 69.26, 90.87, 35.36, 68.51, 117.44, 37.76, 88.51, 85.61, 61.23, 65.75, 107.08, 83.86, 140.43, 68.24, 41.03, 118.28, 97.39, 72.45, 80.84, 96.31, 99.89, 40.23, 54.11, 62.14, 64.64, 68.79, 102.05, 43.64, 115.75, 58.58, 81.36, 66.67, 91.34, 86.61, 90.52, 99.72, 72.28, 101.15, 118.65, 80.0, 100.17, 99.31, 74.03, 49.66, 54.6]
# ...

# %%
NewValue=[]
n=0
m=0
while n< len(MSRP) and m< len(buyPrice):
        margin=MSRP[n]-buyPrice[m]
        percentage_margin=margin/buyPrice[m]
        NewValue.append(percentage_margin)
        n=n+1
        m=m+1
print(NewValue)
# Out:
# [0.9606637984019668, 1.1738689389328465, 0.7240179736193653, 1.1276642496154692, 0.5873015873015872, 0.4285438019725392, 1.040801342563457, 1.1738675593681347, 0.7544287548138636, 1.2728232986268297, 0.694862014808167, 0.562533262373603, 1.0833232992173392, 1.4999999999999998, 1.127468581687612, 0.9608377319938703, 1.0001714383679068, 0.694886839899413, 0.6948201913559882, 1.2221764220939815, 0.8865979381443301, 1.0407661446874596, 0.9607843137254901, 0.4285714285714286, 0.5150708275641708, 0.6129445374839916, 0.8180180180180181, 0.6394603259417581, 1.17390560875513, 1.4386035313001604, 0.7240816326530614, 1.4997936442426745, 1.3256615214994487, 1.3255813953488373, 0.6668311944718658, 0.8183406113537117, 0.6667312536330168, 0.7240698057293381, 0.9998535871156663, 1.1738125802310653, 0.8868619540431503, 0.492599171107164, 0.6393476044852192, 0.7241918665276329, 1.0001360729350934, 1.272844272844273, 0.8867981790591805, 0.6393620315887273, 0.5624456048738034, 1.1273693943596856, 0.6667
# ...

# %%
average_margin=sum(NewValue)/len(NewValue)
print(average_margin)
# Out:
# 0.8870239217133998

# %%
run("SELECT COUNT(DISTINCT(productname)) as Total from products")
# Out:
#    Total
# 0    110

# %%
run("SELECT *from customers")
# Out:
#      customerNumber                        customerName  contactLastName  \
# 0               103                   Atelier graphique          Schmitt
# 1               112                  Signal Gift Stores             King
# 2               114          Australian Collectors, Co.         Ferguson
# 3               119                   La Rochelle Gifts          Labrune
# 4               121                  Baane Mini Imports       Bergulfsen
# 5               124        Mini Gifts Distributors Ltd.           Nelson
# 6               125                  Havel & Zbyszek Co  Piestrzeniewicz
# 7               128                Blauer See Auto, Co.           Keitel
# 8               129                     Mini Wheels Co.           Murphy
# 9               131                   Land of Toys Inc.              Lee
# 10              141              Euro+ Shopping Channel           Freyre
# 11              144            Volvo Model Replicas, Co         Berglund
# ...

# %%
run("SELECT customername, city from customers WHERE salesRepEmployeeNumber IS NULL")
# Out:
#                       customername              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# ...

# %%
run("SELECT *from employees")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
run("SELECT CONCAT(firstName,' ',lastName) AS fullName FROM employees WHERE jobTitle LIKE'%VP%'or jobTitle LIKE '%Manager%'")
# Out:
#             fullName
# 0     Mary Patterson
# 1      Jeff Firrelli
# 2  William Patterson
# 3      Gerard Bondur
# 4        Anthony Bow

# %%
run("SELECT * from orders")
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104  2003-01-31   2003-02-09  2003-02-01     Shipped
# 5          10105  2003-02-11   2003-02-21  2003-02-12     Shipped
# 6          10106  2003-02-17   2003-02-24  2003-02-21     Shipped
# 7          10107  2003-02-24   2003-03-03  2003-02-26     Shipped
# 8          10108  2003-03-03   2003-03-12  2003-03-08     Shipped
# 9          10109  2003-03-10   2003-03-19  2003-03-11     Shipped
# 10         10110  2003-03-18   2003-03-24  2003-03-20     Shipped
# 11         10111  2003-03-25   2003-03-31  2003-03-30     Shipped
# 12         10112  2003-03-24   2003-04-03  2003-03-29     Shipped
# ...

# %%
run("SELECT orderNumber from orders where customerNumber IN (SELECT customerNumber from payments WHERE amount>5000)" )
# Out:
#      orderNumber
# 0          10123
# 1          10298
# 2          10345
# 3          10124
# 4          10278
# 5          10346
# 6          10120
# 7          10125
# 8          10223
# 9          10342
# 10         10347
# 11         10275
# 12         10315
# 13         10375
# 14         10425
# 15         10103
# 16         10158
# 17         10309
# 18         10325
# 19         10113
# 20         10135
# 21         10142
# 22         10182
# 23         10229
# 24         10271
# 25         10282
# 26         10312
# 27         10335
# 28         10357
# 29         10368
# ..           ...
# 294        10242
# 295        10319
# 296        10126
# 297        10214
# 298        10348
# 299        10166
# 300        10321
# 301        10388
# 302        10193
# 303        10265
# 304        10415
# 305        10157
# 306        10218
# 307        10199
# 308        10215
# 309        10184
# 310        10303
# 311        10109
# 312        10236
# 313        10331
# ...
